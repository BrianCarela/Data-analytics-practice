# %% [markdown]
# # 🔁 02_00.5 — DataFrame Skills: Repetition Edition
# ### Data Analyst Curriculum | Pandas Practice
#
# ---
#
# ### What this notebook is for
# Every skill from 02_00 — but with **3 exercises each** instead of 1.
# The goal is simple: by the end, reading a question should immediately
# tell you which method to reach for.
#
# ### The dataset
# A small bookstore — 10 orders. Small enough to see everything,
# but with enough variety and duplicates to make groupby interesting.
#
# ---

# %% [markdown]
# ## 🔧 Setup

# %%
import pandas as pd

data = {
    'title':    ['Dune', 'Educated', '1984', 'Dune', 'Sapiens', 'Educated',
                 'The Alchemist', '1984', 'Sapiens', 'The Alchemist'],
    'genre':    ['sci-fi', 'memoir', 'sci-fi', 'sci-fi', 'nonfiction', 'memoir',
                 'fiction', 'sci-fi', 'nonfiction', 'fiction'],
    'price':    [18.00, 16.00, 12.00, 18.00, 20.00, 16.00, 14.00, 12.00, 20.00, 14.00],
    'quantity': [2, 1, 3, 1, 2, 4, 1, 2, 3, 2],
    'format':   ['hardcover', 'paperback', 'paperback', 'paperback', 'hardcover',
                 'paperback', 'paperback', 'hardcover', 'hardcover', 'paperback'],
}

df = pd.DataFrame(data)
# df # fix scrolling on my phone

# %% [markdown]
# ## 🔍 Section 1: Inspecting a DataFrame
#
# Quick reminder of the inspection tools:
# - `df.shape` → (rows, columns)
# - `df.info()` → column names, data types, non-null counts
# - `df.describe()` → summary stats for numeric columns
# - `df.head(n)` → first n rows
# - `df.tail(n)` → last n rows
# - `df.isnull().sum()` → count of missing values per column

# %% [markdown]
# ### 🏋️ Exercise 1a
# Print the number of rows and columns in `df` as a sentence.
# Expected output: `"This dataset has 10 rows and 5 columns."`
#
# ```python
# # Your code here
# ```

# %%
# Your code here
print(f"this dataset has {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# this dataset has 10 rows and 5 columns

# %% [markdown]
# ### 🏋️ Exercise 1b
# Print only the column names and their data types.
# *Hint: one of the inspection methods shows this.*
#
# ```python
# # Your code here
# ```

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     10 non-null     object
#  1   genre     10 non-null     object
#  2   price     10 non-null     float64
#  3   quantity  10 non-null     int64
#  4   format    10 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 532.0+ bytes

# %% [markdown]
# ### 🏋️ Exercise 1c
# Print the average and maximum price using `df.describe()`.
# Then verify those numbers by calling `.mean()` and `.max()` directly on the price column.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
print(df['price'].describe())
print('average price:')
print(df['price'].mean())
print('max price:')
print(df['price'].max())
# Out:
# count    10.000000
# mean     16.000000
# std       2.981424
# min      12.000000
# 25%      14.000000
# 50%      16.000000
# 75%      18.000000
# max      20.000000
# Name: price, dtype: float64
# average price:
# 16.0
# max price:
# 20.0

# %% [markdown]
# ## 🎯 Section 2: Selecting Columns and Rows
#
# Quick reminder:
# - `df['col']` → one column (Series)
# - `df[['col1', 'col2']]` → multiple columns (DataFrame)
# - `df.iloc[n]` → row by position
# - `df.loc[n]` → row by index label

# %% [markdown]
# ### 🏋️ Exercise 2a
# Select just the `title` and `price` columns and display them.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
df[['title', 'price']]
# Out:
#            title  price
# 0           Dune   18.0
# 1       Educated   16.0
# 2           1984   12.0
# 3           Dune   18.0
# 4        Sapiens   20.0
# 5       Educated   16.0
# 6  The Alchemist   14.0
# 7           1984   12.0
# 8        Sapiens   20.0
# 9  The Alchemist   14.0

# %% [markdown]
# ### 🏋️ Exercise 2b
# Print the total quantity sold across all rows using the `quantity` column.
# Then print the most expensive price in the dataset.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
print(f"total amount of items sold: {df['quantity'].sum()}")
print(f"most expensive price: {df['price'].max():,.2f}")
# Out:
# total amount of items sold: 21
# most expensive price: 20.00

# %% [markdown]
# ### 🏋️ Exercise 2c
# Retrieve the 3rd row using `.iloc[]` and the last row using `.iloc[]`.
# Then retrieve the row with index label 7 using `.loc[]`.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
print(f"3rd row item: \n{df.iloc[2]}")
print(f"last row item: \n{df.iloc[-1]}")
print(f"index 7: \n{df.loc[7]}")
# Out:
# 3rd row item:
# title            Dune
# genre          sci-fi
# price            18.0
# quantity            1
# format      paperback
# Name: 3, dtype: object
# last row item:
# title       The Alchemist
# genre             fiction
# price                14.0
# quantity                2
# format          paperback
# Name: 9, dtype: object
# index 7:
# title            1984
# genre          sci-fi
# price            12.0
# quantity            2
# format      hardcover
# Name: 7, dtype: object

# %% [markdown]
# ## 🔎 Section 3: Filtering Rows
#
# Quick reminder:
# - `df[df['col'] == value]` → rows where condition is True
# - `df[(condition1) & (condition2)]` → AND
# - `df[(condition1) | (condition2)]` → OR

# %% [markdown]
# ### 🏋️ Exercise 3a
# Filter `df` to only hardcover books.
# Print how many there are and their average price.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
hardcover = df[df['format'] == 'hardcover']
print(f"number of hardcover books: {len(hardcover['quantity'])}")
print(f"hardcover book avg price: {hardcover['price'].mean():,.2f}")
# Out:
# number of hardcover books: 4
# hardcover book avg price: 17.50

# %% [markdown]
# ### 🏋️ Exercise 3b
# Filter `df` to books priced at $15.00 or more.
# Display the result — how many rows matched?
#
# ```python
# # Your code here
# ```

# %%
# Your code here
big_books = df[df['price'] >= 15]

print(f"there are {len(big_books)} rows")
# Out:
# there are 6 rows

# %% [markdown]
# ### 🏋️ Exercise 3c
# Filter `df` to sci-fi books that are paperback.
# Then filter `df` to books that are either memoir OR cost less than $14.00.
# Print the row counts for both results.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
paper_scifi = df[(df['format'] == 'paperback') & (df['genre'] == 'sci-fi')]
print(f"there are {len(paper_scifi)} sci-fi books in paperback format")

cheap_or_mem = df[(df['price'] < 14) | (df['genre'] == 'memoir')]
print(f"there are {len(cheap_or_mem)} books that are either cheap or a memoir")
# Out:
# there are 2 sci-fi books in paperback format
# there are 4 books that are either cheap or a memoir

# %% [markdown]
# ## ➕ Section 4: Adding Columns with `.apply()`
#
# Quick reminder:
# ```python
# def my_function(value):
#     return something
#
# df['new_col'] = df['existing_col'].apply(my_function)
# ```
# You pass the function name — no parentheses. Pandas calls it on every row.

# %% [markdown]
# ### 🏋️ Exercise 4a
# Write a function called `price_label` that returns:
# - `'cheap'` if price is under $14.00
# - `'mid'` if price is $14.00 to $17.99
# - `'pricey'` if price is $18.00 or more
#
# Apply it to the `price` column and store it in a new column called `price_label`.
# Display `df` to confirm.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
def price_label(price):
  if price < 14:
    return 'cheap'
  elif price < 18:
    return 'mid'
  else:
    return 'pricey'

df['price_label'] = df['price'].apply(price_label)
# df # easier view on mobile

# %% [markdown]
# ### 🏋️ Exercise 4b
# Write a function called `is_bulk` that returns `True` if quantity is 3 or more,
# and `False` otherwise.
#
# Apply it to create a new column called `bulk_order`.
# Then print how many bulk orders there are using `.sum()`.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
def is_bulk(quantity):
  if quantity >= 3:
    return True
  else:
    return False

df['bulk_orders'] = df['quantity'].apply(is_bulk)

print(f"number of bulk orders: {df['bulk_orders'].sum()}")
# Out:
# number of bulk orders: 3

# %% [markdown]
# ### 🏋️ Exercise 4c
# Write a function called `format_label` that returns:
# - `'HC'` if the format is `'hardcover'`
# - `'PB'` if the format is `'paperback'`
#
# Apply it to create a new `short_format` column.
# Then display only the `title`, `format`, and `short_format` columns to verify.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
def format_label(format):
  if format == 'hardcover':
    return 'HC'
  elif format == 'paperback':
    return 'PB'

df['short_format'] = df['format'].apply(format_label)
df[['title', 'format', 'short_format']]
# Out:
#            title     format short_format
# 0           Dune  hardcover           HC
# 1       Educated  paperback           PB
# 2           1984  paperback           PB
# 3           Dune  paperback           PB
# 4        Sapiens  hardcover           HC
# 5       Educated  paperback           PB
# 6  The Alchemist  paperback           PB
# 7           1984  hardcover           HC
# 8        Sapiens  hardcover           HC
# 9  The Alchemist  paperback           PB

# %% [markdown]
# ## 📊 Section 5: Summarizing with `.groupby()`
#
# Quick reminder:
# ```python
# df.groupby('group_col')['value_col'].aggregation()
# ```
# Common aggregations: `.mean()` `.sum()` `.count()` `.min()` `.max()`
#
# After groupby, the result is a Series — the group values become the index.

# %% [markdown]
# ### 🏋️ Exercise 5a
# Find the total quantity sold per genre.
# Which genre had the most copies sold?
#
# ```python
# # Your code here
# ```

# %%
# Your code here
sales_by_genre = df.groupby('genre')['quantity'].sum()
# this gives the genre label, which can be used to get just the row
top_genre = sales_by_genre.idxmax()
print(f"top genre: {top_genre} with {sales_by_genre[top_genre]} sales")
# Out:
# top genre: sci-fi with 8 sales

# %% [markdown]
# ### 🏋️ Exercise 5b
# Find the average price per format (hardcover vs paperback).
# Print a sentence stating which format costs more on average.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
price_per_format = df.groupby('format')['price'].mean()
print(f"the format {price_per_format.idxmax()} costs more on average than {price_per_format.idxmin()}")
# Out:
# the format hardcover costs more on average than paperback

# %% [markdown]
# ### 🏋️ Exercise 5c
# First add a `revenue` column (`price × quantity`).
# Then find the total revenue per genre.
# Display the results sorted highest to lowest.
#
# ```python
# # Your code here
# ```

# %%
# Your code here

df['revenue'] = df['price'] * df['quantity']

rev_per_genre = df.groupby('genre')['revenue'].sum()
rev_per_genre.sort_values(ascending=False)
# Out:
# genre
# sci-fi        114.0
# nonfiction    100.0
# memoir         80.0
# fiction        42.0
# Name: revenue, dtype: float64

# %% [markdown]
# ## 🔢 Section 6: Finding Extremes with `.idxmax()` and `.idxmin()`
#
# Quick reminder:
# - `.idxmax()` → returns the **index label** of the highest value
# - `.idxmin()` → returns the **index label** of the lowest value
# - Use `.loc[]` to retrieve the full row using that label
#
# Works on a plain column AND on the result of a groupby.

# %% [markdown]
# ### 🏋️ Exercise 6a
# Find the row with the highest quantity using `.idxmax()`.
# Use `.loc[]` to retrieve that full row.
# Print a sentence: `"The highest quantity order was X copies of [title]."`
#
# ```python
# # Your code here
# ```

# %%
# Your code here
max_quant = df['quantity'].idxmax()
mq_row = df.loc[max_quant]
print(f"The highest quantity order was {mq_row['quantity']} copies of {mq_row['title']}")
# Out:
# The highest quantity order was 4 copies of Educated

# %% [markdown]
# ### 🏋️ Exercise 6b
# Find the row with the lowest price using `.idxmin()`.
# Print the title and price of that book.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
min_price = df['price'].idxmin()
mp_row = df.loc[min_price]
print(f"the book {mp_row['title']} has the lowest price at {mp_row['price']}")
# Out:
# the book 1984 has the lowest price at 12.0

# %% [markdown]
# ### 🏋️ Exercise 6c
# Using the `revenue` column from Section 5:
# 1. Find the total revenue per title using `.groupby()`
# 2. Use `.idxmax()` on that result to find the best-selling title
# 3. Print: `"The best-selling title is [title] with $X in total revenue."`
#
# ```python
# # Your code here
# ```

# %%
# Your code here
rev_per_title = df.groupby('title')['revenue'].sum()
max_rev_title = rev_per_title.idxmax() # already a series, dont need to specify a revenue column for idxmax
print(f"The best selling title is {max_rev_title} with ${rev_per_title[max_rev_title]} in total revenue")
# Out:
# The best selling title is Sapiens with $100.0 in total revenue

# %% [markdown]
# ## ⛓️ Section 7: Chaining Operations
#
# Quick reminder — chain methods one after another, each working on the previous result:
# ```python
# (df[df['col'] == value]
#    .groupby('group_col')['value_col']
#    .sum()
#    .sort_values(ascending=False))
# ```
# Outer parentheses let you split across lines.

# %% [markdown]
# ### 🏋️ Exercise 7a
# In one chain: filter to paperback books only, then find the total quantity per genre,
# sorted highest to lowest.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
(df[df['format'] == 'paperback']
 .groupby('genre')['quantity']
 .sum()
 .sort_values(ascending=False))
# Out:
# genre
# memoir     5
# sci-fi     4
# fiction    3
# Name: quantity, dtype: int64

# %% [markdown]
# ### 🏋️ Exercise 7b
# In one chain: filter to books priced over $15, then find the average revenue per genre.
#
# ```python
# # Your code here
# ```

# %%
# Your code here
(df[df['price'] > 15]
 .groupby('genre')['revenue']
 .mean())
# Out:
# genre
# memoir        40.0
# nonfiction    50.0
# sci-fi        27.0
# Name: revenue, dtype: float64

# %% [markdown]
# ### 🏋️ Exercise 7c
# In one chain: filter to sci-fi books, find total revenue per title, sort descending.
# Then print which sci-fi title earned the most.
#
# ```python
# # Your code here
# ```

# %%
# Your code here

# %% [markdown]
# ## 🏁 Capstone: Bookstore Report
#
# Answer all of the following using what you've practiced.
# Then write 3–4 print statements presenting your findings to the bookstore owner.
#
# 1. What is the average revenue per genre? Which genre earns the most on average?
# 2. Among hardcover books only, which title has the highest total revenue?
# 3. What percentage of orders are bulk orders? *(bulk = quantity ≥ 3)*
# 4. Which format (hardcover or paperback) generates more total revenue?
#
# ```python
# # Your code here
# ```

# %%
# Your code here

# %% [markdown]
# ---
# ## ✅ Done
#
# If you could work through all of those without getting stuck, you're ready for 02_01.
# The insurance dataset is just bigger — the operations are identical.
